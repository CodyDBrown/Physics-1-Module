# %%
import one_d_motion as od
import projectile
import numpy as np

# %%
od.time(v0 = 30, xf = 0)
# Out:
# (-0.0, 6.122448979591836)

# %%
od.acceleration(v0 = 60, t = 4, vf = 0)
# Out:
# -15.0

# %%
od.acceleration(xf = 402, t = 4.44)
# Out:
# 40.784027270513754

# %%
od.velocity(xf = 125, a = 10)
# Out:
# 50.0

# %%
projectile.height(44.7, 60)
# Out:
# 76.45752551020408

# %%
projectile.flight_time(44.7, 60)
# Out:
# (-0.0, 7.900272561053961)

# %%
projectile.distance(44.7, 60)
# Out:
# 176.57109173955604

# %%
vx = 15*np.cos(np.radians(37))

# %%
vx
# Out:
# 11.979532650709393

# %%
projectile.plot_trajectory(44.7, 60)
